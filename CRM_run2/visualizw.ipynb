# %%
import pandas as pd

# %%
df = pd.read_csv("HistoricalPrices.csv")

# %%
df
# Out:
#         Date      Open      High       Low     Close
# 0   06/26/24  39063.15  39183.74  38908.99  39127.80
# 1   06/25/24  39398.79  39423.26  38997.23  39112.16
# 2   06/24/24  39184.49  39571.23  39184.49  39411.21
# 3   06/21/24  39208.51  39257.18  39061.67  39150.33
# 4   06/20/24  38804.73  39232.50  38778.46  39134.76
# ..       ...       ...       ...       ...       ...
# 56  04/05/24  38664.98  39040.17  38602.18  38904.04
# 57  04/04/24  39343.60  39421.35  38559.42  38596.98
# 58  04/03/24  39139.59  39305.76  39017.13  39127.14
# 59  04/02/24  39256.27  39256.27  39051.70  39170.24
# 60  04/01/24  39807.93  39815.00  39491.22  39566.85
#
# [61 rows x 5 columns]

# %%
df[' Open']
# Out:
# 0     39063.15
# 1     39398.79
# 2     39184.49
# 3     39208.51
# 4     38804.73
#         ...
# 56    38664.98
# 57    39343.60
# 58    39139.59
# 59    39256.27
# 60    39807.93
# Name:  Open, Length: 61, dtype: float64

# %%
df = df.rename(
    columns={
        ' Open':'Open',
        ' High':'High',
        ' Low':'Low',
        ' Close':'Close'
    }
)

# %%
df['Open']
# Out:
# 0     39063.15
# 1     39398.79
# 2     39184.49
# 3     39208.51
# 4     38804.73
#         ...
# 56    38664.98
# 57    39343.60
# 58    39139.59
# 59    39256.27
# 60    39807.93
# Name: Open, Length: 61, dtype: float64

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by = 'Date')
# Out:
# /var/folders/2g/jd45h1nd7hldn34bs81klw5m0000gn/T/ipykernel_2276/798441811.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#          Date      Open      High       Low     Close
# 60 2024-04-01  39807.93  39815.00  39491.22  39566.85
# 59 2024-04-02  39256.27  39256.27  39051.70  39170.24
# 58 2024-04-03  39139.59  39305.76  39017.13  39127.14
# 57 2024-04-04  39343.60  39421.35  38559.42  38596.98
# 56 2024-04-05  38664.98  39040.17  38602.18  38904.04
# ..        ...       ...       ...       ...       ...
# 4  2024-06-20  38804.73  39232.50  38778.46  39134.76
# 3  2024-06-21  39208.51  39257.18  39061.67  39150.33
# 2  2024-06-24  39184.49  39571.23  39184.49  39411.21
# 1  2024-06-25  39398.79  39423.26  38997.23  39112.16
# 0  2024-06-26  39063.15  39183.74  38908.99  39127.80
#
# [61 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 60 to 0
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    61 non-null     datetime64[ns]
#  1   Open    61 non-null     float64
#  2   High    61 non-null     float64
#  3   Low     61 non-null     float64
#  4   Close   61 non-null     float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 2.9 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Date'],df['Close'],label = 'close')
plt.plot(df['Date'],df['Open'],label='open')
plt.legend()
plt.show()

# %% [markdown]
# ## Bar Chart
# - vertical
# - horizontal

# %%
from calendar import month_name

# %%
df['Month'] = pd.Categorical(df['Date'].dt.month_name(),month_name[1:])

# %%
df
# Out:
#          Date      Open      High       Low     Close  Month
# 60 2024-04-01  39807.93  39815.00  39491.22  39566.85  April
# 59 2024-04-02  39256.27  39256.27  39051.70  39170.24  April
# 58 2024-04-03  39139.59  39305.76  39017.13  39127.14  April
# 57 2024-04-04  39343.60  39421.35  38559.42  38596.98  April
# 56 2024-04-05  38664.98  39040.17  38602.18  38904.04  April
# ..        ...       ...       ...       ...       ...    ...
# 4  2024-06-20  38804.73  39232.50  38778.46  39134.76   June
# 3  2024-06-21  39208.51  39257.18  39061.67  39150.33   June
# 2  2024-06-24  39184.49  39571.23  39184.49  39411.21   June
# 1  2024-06-25  39398.79  39423.26  38997.23  39112.16   June
# 0  2024-06-26  39063.15  39183.74  38908.99  39127.80   June
#
# [61 rows x 6 columns]

# %%
df["Month"].value_counts()
# Out:
# Month
# April        22
# May          22
# June         17
# January       0
# February      0
# March         0
# July          0
# August        0
# September     0
# October       0
# November      0
# December      0
# Name: count, dtype: int64

# %%
dfMonth = df.groupby('Month').mean().reset_index()
# Out:
# /var/folders/2g/jd45h1nd7hldn34bs81klw5m0000gn/T/ipykernel_2276/1375376482.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dfMonth = df.groupby('Month').mean().reset_index()

# %%
dfMonth
# Out:
#         Month                          Date          Open          High  \
# 0     January                           NaT           NaN           NaN
# 1    February                           NaT           NaN           NaN
# 2       March                           NaT           NaN           NaN
# 3       April 2024-04-14 22:54:32.727272704  38504.349545  38628.500455
# 4         May 2024-05-15 20:43:38.181818112  39127.017273  39291.536818
# 5        June 2024-06-13 21:10:35.294117632  38848.885294  39001.290588
# 6        July                           NaT           NaN           NaN
# 7      August                           NaT           NaN           NaN
# 8   September                           NaT           NaN           NaN
# 9     October                           NaT           NaN           NaN
# 10   November                           NaT           NaN           NaN
# 11   December                           NaT           NaN           NaN
#
#              Low         Close
# ...

# %%
plt.bar(dfMonth['Month'],height=dfMonth['Close'])
plt.xlabel('Months')
plt.ylabel('Closing Price')
plt.title('Bar Chart')
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(df['Open'],df['Close'])
plt.show()

# %% [markdown]
# ## Trend Line:
# - least square polynomial fit
# - np.polyfit()
# - np.poly1d()

# %%
import numpy as np

# %%
z = np.polyfit(df['Open'], df['Close'], 1)
p = np.poly1d(z)

# %%
plt.scatter(df['Open'],df['Close'])
plt.plot(df['Open'],p(df['Open']),color = 'red')
plt.savefig("Scatter.png")
plt.show()

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',size='size',sizes=(50,200),data=tips)
plt.xlabel("Total Bill")
plt.ylabel("Tips")
plt.title("Tips vs Total Bill")
# Out:
# Text(0.5, 1.0, 'Tips vs Total Bill')

# %%
sns.lineplot(x="Open",y="Close",hue="Month",data=dfMonth)
plt.show()

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint',y='signal',hue='event',style='region',markers=True,dashes=False,data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.barplot(x='class',y='fare',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',hue='sex', palette='muted',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>
